# %%
pip install pmdarima
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt
from sklearn.model_selection import train_test_split
from statsmodels.tools.eval_measures import rmse
import matplotlib.pyplot as plt
import pmdarima as pm
import xgboost as xgb

# %%
# Load data
data = pd.read_csv('macedonia-air-quality1.csv', dayfirst=True)
data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)
data.columns = data.columns.str.strip()

# %%
# Drop unnecessary columns
data.drop(['pm25', 'o3', 'no2', 'so2', 'co'], axis=1, inplace=True)
data.sort_index(inplace=True)

# %%
frequency = pd.infer_freq(data.index)

# Reindex the DataFrame to ensure that the datetime index covers the entire range without any gaps
data = data.asfreq(frequency)

# Use linear interpolation to fill missing values
data['pm10'] = pd.to_numeric(data['pm10'], errors='coerce')

# Specify the frequency value
frequency = 'D'  # Replace with the appropriate frequency for your data

# Reindex the DataFrame to ensure that the datetime index covers the entire range without any gaps
data = data.asfreq(frequency)

# Use linear interpolation to fill missing values
data['pm10'] = data['pm10'].interpolate(method='linear')

# %%
desired_date = pd.to_datetime('2022-07-02')  # Replace with the desired date

if desired_date in data.index:
    entry = data.loc[desired_date]
    print(entry)
else:
    print(f"No entry found for {desired_date.date()}.")
# Out:
# pm10    38.833333
# Name: 2022-07-02 00:00:00, dtype: float64

# %%
# Limit unusual values
data['pm10'] = data['pm10'].apply(lambda x: min(int(x) if isinstance(x, str) and x.strip() != '' else int(x) if isinstance(x, float) else 0, 350))

# %%
plt.figure(figsize=(12,6))
plt.plot(data.index, data['pm10'])
plt.title('PM10 Particles Over Time')
plt.ylabel('PM10 Particle Level')
plt.grid(True)
plt.show()

# %%
auto_model = pm.auto_arima(train['pm10'], 
                           seasonal=True, m=12,
                           d=None, D=None, 
                           max_p=2, max_q=2, max_P=2, max_Q=2,
                           trace=True,
                           error_action='ignore',
                           suppress_warnings=True)

# Print the best model's parameters
print(auto_model.summary())
# Out:
# Performing stepwise search to minimize aic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7032\3385733146.py in <module>
# ----> 1 auto_model = pm.auto_arima(train['pm10'],
#       2                            seasonal=True, m=12,
#       3                            d=None, D=None,
#       4                            max_p=2, max_q=2, max_P=2, max_Q=2,
#       5                            trace=True,
#
# ...

# %%
smodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                   y   No. Observations:                 2907
# Model:             SARIMAX(3, 0, 1)x(2, 1, [], 12)   Log Likelihood              -13173.450
# Date:                             Sat, 24 Jun 2023   AIC                          26360.900
# Time:                                     21:46:39   BIC                          26402.696
# Sample:                                          0   HQIC                         26375.961
#                                             - 2907
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4245      0.049     28.949      0.000       1.328       1.521
# ...

# %%
# Split data into train / test sets
train_size = int(len(data) * 0.8)
train, test = data[0:train_size], data[train_size:len(data)]

train.index = pd.DatetimeIndex(train.index.values, freq='your_frequency_here')
test.index = pd.DatetimeIndex(test.index.values, freq='your_frequency_here')

# %%
# Create a model
# model_arima = SARIMAX(train, order=(2, 1, 2), seasonal_order=(0, 0, 1, 12))
# model_fit_arima = model_arima.fit(disp=False)

# # Predict air quality index
# forecast_arima = model_fit_arima.get_prediction(start=pd.to_datetime(test.index[0]), 
#                                                 end=pd.to_datetime(test.index[-1]),
#                                                 dynamic=False)

# # Calculate metrics
# mae_arima = mean_absolute_error(test, forecast_arima.predicted_mean)
# rmse_arima = sqrt(mean_squared_error(test, forecast_arima.predicted_mean))

# print('ARIMA MAE: %.3f' % mae_arima)
# print('ARIMA RMSE: %.3f' % rmse_arima)

# %%
# Create the supervised learning dataset
X_train, y_train = create_supervised_dataset(train_values, n_lag)
X_test, y_test = create_supervised_dataset(test_values, n_lag)

# Define the number of lag observations
n_lag = 12

# %%
train_values = train['pm10'].values
test_values = test['pm10'].values

# Create the supervised learning dataset
y_test_series = pd.Series(y_test, index=test.index[n_lag:])
y_pred_series = pd.Series(y_pred, index=test.index[n_lag:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1504\4215421947.py in <module>
#       4 # Create the supervised learning dataset
#       5 y_test_series = pd.Series(y_test, index=test.index[n_lag:])
# ----> 6 y_pred_series = pd.Series(y_pred, index=test.index[n_lag:])
#
# NameError: name 'y_pred' is not defined

# %%
model_xgboost = xgb.XGBRegressor()
model_xgboost.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1504\466508918.py in <module>
#       1 model_xgboost = xgb.XGBRegressor()
# ----> 2 model_xgboost.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
y_pred = model_xgboost.predict(X_test)

# Calculate metrics
mae_xgboost = mean_absolute_error(y_test, y_pred)
rmse_xgboost = sqrt(mean_squared_error(y_test, y_pred))

print('XGBoost MAE: %.3f' % mae_xgboost)
print('XGBoost RMSE: %.3f' % rmse_xgboost)
# Out:
# XGBoost MAE: 10.481
# XGBoost RMSE: 15.157

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_series.index, y_test_series, label='Actual')
plt.plot(y_pred_series.index, y_pred_series, color='red', label='Predicted')
plt.xlabel('Date')
plt.ylabel('pm10')
plt.title('PM10 Particle Predictions vs Actuals')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Fit a SARIMAX model
model = SARIMAX(train['pm10'], order=(2, 1, 2), seasonal_order=(1, 0, 2, 12))
model_fit = model.fit(disp=False)

# %%
start_idx = test.index[0]
end_idx = test.index[-1]
predictions = model_fit.get_prediction(start=start_idx, end=end_idx).predicted_mean

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test['pm10'], predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 26.827

# %%
test['pm10'].mean()
# Out:
# 39.250280583613915

# %%
# Plot the results
plt.figure(figsize=(12,6))
plt.plot(test.index, test['pm10'], label='Actual')
plt.plot(test.index, predictions, color='red', label='Predicted')
plt.legend(loc='best')
plt.title('PM10 Particle Predictions vs Actuals')
plt.grid(True)
plt.show()
